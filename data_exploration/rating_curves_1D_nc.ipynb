# %%
import os
import xarray
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds = xarray.open_dataset('hydroprop-fulltable.nc')

# %%
df = ds.to_dataframe()

# %%
df.head()
# Out:
#         CatchId   Stage  NumCells    SurfaceArea        BedArea        Volume  \
# index
# 0      19679365  0.0000       427   37108.229365   37110.131936      0.000000
# 1      19679365  0.3048       481   41801.091635   41804.123018  11921.873035
# 2      19679365  0.6096       662   57530.763955   57550.358546  26564.035362
# 3      19679365  0.9144      1042   90554.491880   90632.696208  48894.018637
# 4      19679365  1.2192      1597  138786.386462  138979.232138  83528.429226
#
#           SLOPE  LENGTHKM  AREASQKM  Roughness   TopWidth  WettedPerimeter  \
# index
# 0      0.005133     3.945    4.9545       0.05   9.406395         9.406878
# 1      0.005133     3.945    4.9545       0.05  10.595967        10.596736
# 2      0.005133     3.945    4.9545       0.05  14.583210        14.588177
# 3      0.005133     3.945    4.9545       0.05  22.954244        22.974067
# 4      0.005133     3.945    4.9545       0.05  35.180326        35.229210
#
#          WetArea  HydraulicRadius  Discharge
# index
# 0       0.000000         0.000000   0.000000
# 1       3.022021         0.285184   1.876145
# 2       6.733596         0.461579   5.762748
# 3      12.393921         0.539474  11.769044
# 4      21.173239         0.601014  21.607051

# %%
# No. of catchments or flow segments
len(df.CatchId.unique())
# Out:
# 2638933

# %%
# Groupby CatchId. This should return number of groups equal to the number of the flow segments
grpd = df.groupby('CatchId')
len(grpd)
# Out:
# 2638933

# %%
grpd.count().head()
# Out:
#          Stage  NumCells  SurfaceArea  BedArea  Volume  SLOPE  LENGTHKM  \
# CatchId
# 101         83        83           83       83      83     83        83
# 179         83        83           83       83      83     83        83
# 181         83        83           83       83      83     83        83
# 183         83        83           83       83      83     83        83
# 185         83        83           83       83      83     83        83
#
#          AREASQKM  Roughness  TopWidth  WettedPerimeter  WetArea  \
# CatchId
# 101            83         83        83               83       83
# 179            83         83        83               83       83
# 181            83         83        83               83       83
# 183            83         83        83               83       83
# 185            83         83        83               83       83
#
#          HydraulicRadius  Discharge
# CatchId
# 101                   83         83
# 179                   83         83
# 181                   83         83
# 183                   83         83
# 185                   83         83

# %%
# Select on the first 50 groups to plot due to memory issue
selected_grpd = pd.concat( [ grpd.get_group(group) for i,group in enumerate( grpd.groups) if i < 15 ] ).groupby('CatchId')

# %%
# Plot All Rating Curves on the same plot

figsize=(20,6)
fontsize=18

fig,  ax = plt.subplots(figsize=figsize)
ax.set_xlabel('Depth (ft)', fontsize=fontsize)
ax.set_ylabel('Discharge (cfs)', fontsize=fontsize)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.grid(which='major', color='lightgrey', linestyle='--', linewidth=2)


for name, data in selected_grpd:
    
    ax.plot(data.Stage.values, data['Discharge'].values, label = "COMID: " + str(name))
    

ax.set_title("Rating Curves for Selected Segments")

ax.legend()
