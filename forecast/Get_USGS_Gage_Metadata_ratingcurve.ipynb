# %% [markdown]
# # Get Gage Datum

# %%
from usgs_nwm import *

# %%
gage = '01651000'
metaData = get_gage_meta(gage)
metaData
# Out:
# {'lat': 42.083333333333336,
#  'lon': 90.63277777777778,
#  'horizontal datum': 'NAD27',
#  'HUC8': '07060006',
#  'drainage area sqmi': 1553.0,
#  'vertical datum': 'NGVD29',
#  'feet above vertical datum': 625.96,
#  'gage': '05418500'}

# %%
#availData = get_gage_available_data(gage) 
#availData

# %%
usgs_rc = get_USGS_ratingcurve(gage)
usgs_rc.head()
# Out:
#    INDEP  SHIFT     DEP  INDEP_SHIFT   INDEP_m  SHIFT_m   DEP_cms  \
# 0   9.25   0.35  287.25         9.60  2.819400  0.10668  8.134014
# 1   9.26   0.35  289.94         9.61  2.822448  0.10668  8.210187
# 2   9.27   0.35  292.64         9.62  2.825496  0.10668  8.286642
# 3   9.28   0.35  295.36         9.63  2.828544  0.10668  8.363664
# 4   9.29   0.35  298.08         9.64  2.831592  0.10668  8.440686
#
#    INDEP_SHIFT_m
# 0       2.926080
# 1       2.929128
# 2       2.932176
# 3       2.935224
# 4       2.938272

# %%
fig, ax = new_plot()
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_SHIFT_m, label='USGS Shifted')
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_m, label='USGS Base')
ax.legend();

# %%
gage = '01649500'
metaData = get_gage_meta(gage)
usgs_rc = get_USGS_ratingcurve(gage)
fig, ax = new_plot()
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_SHIFT_m, label='USGS Shifted')
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_m, label='USGS Base')
ax.legend();

# %%
gage = '01651000'
metaData = get_gage_meta(gage)
usgs_rc = get_USGS_ratingcurve(gage)
fig, ax = new_plot()
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_SHIFT_m, label='USGS Shifted')
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_m, label='USGS Base')
ax.legend();

# %%
gage = '01649500'
metaData = get_gage_meta(gage)
usgs_rc = get_USGS_ratingcurve(gage)
fig, ax = new_plot()
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_SHIFT_m, label=f'{gage} Shifted')
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_m, label=f'{gage} Base')
ax.legend();

gage = '01651000'
metaData = get_gage_meta(gage)
usgs_rc = get_USGS_ratingcurve(gage)
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_SHIFT_m, label=f'{gage} Shifted')
ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_m, label=f'{gage} Base')
ax.legend();

# %% [markdown]
# #### Edge Cases

# %% [raw]
# gage = '01651750'
# metaData = get_gage_meta(gage)
# usgs_rc = get_USGS_ratingcurve(gage)
# fig, ax = new_plot()
# ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_SHIFT_m, label='USGS Shifted')
# ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_m, label='USGS Base')
# ax.legend();

# %% [raw]
# gage = '01651827'
# metaData = get_gage_meta(gage)
# usgs_rc = get_USGS_ratingcurve(gage)
# fig, ax = new_plot()
# ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_SHIFT_m, label='USGS Shifted')
# ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_m, label='USGS Base')
# ax.legend();

# %% [raw]
# gage = '0165258890'
# metaData = get_gage_meta(gage)
# usgs_rc = get_USGS_ratingcurve(gage)
# fig, ax = new_plot()
# ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_SHIFT_m, label='USGS Shifted')
# ax.plot(usgs_rc.DEP_cms, usgs_rc.INDEP_m, label='USGS Base')
# ax.legend();
